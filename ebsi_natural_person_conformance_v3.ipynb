# %% [markdown]
# # EBSI Wallet Conformance (Natural Person)

# %% [markdown]
# > EBSI v2 DID for Natural Person(s) is introduced.

# %% [markdown]
# ## Setup conformance headers

# %%
import uuid
import asyncio
from rich.console import Console

console = Console()

loop = asyncio.get_event_loop()

# str(uuid.uuid4())

headers = {
    "Conformance": str(uuid.uuid4()),
}

# %% [markdown]
# ## Setup wallet

# %%
from ebsi_wallet.main import wallet

# Setup wallet
client = await wallet("init_v2")

# %% [markdown]
# ## ISSUE_011

# %%
from ebsi_wallet.main import conformance
from ebsi_wallet.util import parse_query_string_parameters_from_url

options = {
    "conformance": headers.get("Conformance"),
    "flow_type": "cross-device",
    "credential_type": "pda1"
}

result = await conformance("issuerInitiateV3", headers=headers, options=options)

console.log("issuerInitiate", result)

# session_token = result.replace("openid://", "")
# credential_type = parse_query_string_parameters_from_url(
#     session_token).get("credential_type")[0]
# issuer_url = parse_query_string_parameters_from_url(
#     session_token).get("issuer")[0]

# console.log("credential_type", credential_type)

# options = {
#     "client": client,
#     "credential_type" : credential_type
# }

# result = await conformance("issuerAuthorize", options=options)
# console.log("issuerAuthorize", result)
# Out:
# [01:18:56] issuerInitiate 404 page not found                                                       ]8;id=788839;file:///tmp/ipykernel_54364/2451052359.py\2451052359.py]8;;\:]8;id=462750;file:///tmp/ipykernel_54364/2451052359.py#12\12]8;;\

# %% [markdown]
# ## ISSUE_021

# %%
options = {
    "did_version": client.did_version,
    "code": result["code"]
}

result = await conformance("issuerToken", options=options, headers=headers)
console.log("issuerToken", result)
# Out:
# [01:06:53] issuerToken                                                                              ]8;id=276674;file:///tmp/ipykernel_51399/1256846934.py\1256846934.py]8;;\:]8;id=201970;file:///tmp/ipykernel_51399/1256846934.py#7\7]8;;\
#            {
#                'token_type': 'Bearer',
#                'access_token': 'a3eb7c881eb18c6626c6',
#                'expires_in': 3600,
#                'c_nonce': '93037fc39c140373c4b2',
#                'id_token':
#            'eyJ0eXAiOiJKV1QiLCJhbGciOiJFUzI1NksifQ.eyJpYXQiOjE2NzYyMzA2MTMsInN1YiI6Imh0dHBzOi8vbG9j
#            YWxob3N0OjMwMDAiLCJhdWQiOiJodHRwczovL2xvY2FsaG9zdDozMDAwIiwiaXNzIjoiZGlkOmVic2k6emNmY3dH
#            akxCb2pjenc5eWhtVUZFM1oifQ.A4AGs0n803y2hPsuaBFOJ4kBBgREbdueWcwDl7WDjDCvTxqd6WBM9FgmSzLa0
#            QRHUA-tOVQ1et6t95DsU__zuQ'
#            }

# %% [markdown]
# ## ISSUE_031

# %%
from ebsi_wallet.did_jwt import decode_jwt

options = {
    "c_nonce": result["c_nonce"],
    "client": client,
    "issuer_url": issuer_url,
    "credential_type": credential_type,
}

access_token = result["access_token"]

headers = {
    "Authorization": f"Bearer {access_token}",
    "Conformance": headers["Conformance"]
}

result = await conformance("issuerCredential", options=options, headers=headers)
console.log("issuerCredential", result)

issue_031_credential = result["credential"]

credential = decode_jwt(result["credential"])

console.log("Received credential", credential)
# Out:
#            Ik9mZmljaWFsIHNpZ25hdHVyZSJ9LCJpZCI6ImRpZDplYnNpOnpiWFN0dzVLZ1dKclczVTVZbWJ2QWZnd25CMXRz
#            c1BDUFBWTXFQcmVLRWl1NSJ9LCJjcmVkZW50aWFsU2NoZW1hIjp7ImlkIjoiaHR0cHM6Ly9hcGktY29uZm9ybWFu
#            Y2UuZWJzaS5ldS90cnVzdGVkLXNjaGVtYXMtcmVnaXN0cnkvdjIvc2NoZW1hcy96R1VSN1J4Q1p0d1FGU2R3b3c2
#            M3hGOGhQMmdNdEg1NWluY0tzQUR3cmN3eloiLCJ0eXBlIjoiRnVsbEpzb25TY2hlbWFWYWxpZGF0b3IyMDIxIn0s
#            ImV4cGlyYXRpb25EYXRlIjoiMjAzMy0wMi0xMlQxOTozNjo1M1oifX0.3B3ziZtsKq6bBjsCXImu8qGAcBUp4Taz
#            ZYH9Ocw4W_9AoL88MFk7jnUuUwOHmhRz-bt1MWu7kV3ZcNjV_74HIw',
#                'c_nonce': '210abb51fb58443f9593',
#                'c_nonce_expires_in': 900
#            }
#            Received credential                                                                      ]8;id=350791;file:///tmp/ipykernel_51399/608560569.py\608560569.py]8;;\:]8;id=908045;file:///tmp/ipykernel_51399/608560569.py#24\24]8;;\
#            {
#                'header': {
#                    'alg': 'ES256K',
#                    'typ': 'JWT',
#                    'kid': 'did:ebsi:zcfcwGjLBojczw9yhmUFE3Z#keys-1'
#                },
#                'payload': {
#                    'jti': 'urn:credential:rntuo:6fc77693-eaaf-4a4d-847e-a23237c1f150',
#                    'sub': 'did:ebsi:zbXStw5KgWJrW3U5YmbvAfgwnB1tssPCPPVMqPreKEiu5',
#                    'iss': 'did:ebsi:zcfcwGjLBojczw9yhmUFE3Z',
#                    'nbf': 1676230613,
#                    'exp': 1991849813,
#                    'iat': 1676230613,
#                    'vc': {
#                        '@context': ['https://www.w3.org/2018/credentials/v1'],
#                        'id': 'urn:credential:rntuo:6fc77693-eaaf-4a4d-847e-a23237c1f150',
#                        'type': [
#                            'VerifiableCredential',
#                            'VerifiableAttestation',
#                            'VerifiablePortableDocumentA1'
#                        ],
#                        'issuer': 'did:ebsi:zcfcwGjLBojczw9yhmUFE3Z',
#                        'issuanceDate': '2023-02-12T19:36:53Z',
#                        'validFrom': '2023-02-12T19:36:53Z',
#                        'issued': '2023-02-12T19:36:53Z',
#                        'credentialSubject': {
#                            'section1': {
#                                'personalIdentificationNumber': '1',
#                                'sex': '01',
#                                'surname': 'Dalton',
#                                'forenames': 'Joe Jack William Averell',
#                                'dateBirth': '1985-08-15',
#                                'nationalities': ['BE'],
#                                'stateOfResidenceAddress': {
#                                    'streetNo': 'sss, nnn ',
#                                    'postCode': 'ppp',
#                                    'town': 'ccc',
#                                    'countryCode': 'BE'
#                                },
#                                'stateOfStayAddress': {
#                                    'streetNo': 'sss, nnn ',
#                                    'postCode': 'ppp',
#                                    'town': 'ccc',
#                                    'countryCode': 'BE'
#                                }
#                            },
#                            'section2': {
#                                'memberStateWhichLegislationApplies': 'DE',
#                                'startingDate': '2022-10-09',
#                                'endingDate': '2022-10-29',
#                                'certificateForDurationActivity': True,
#                                'determinationProvisional': False,
#                                'transitionRulesApplyAsEC8832004': False
#                            },
#                            'section3': {
#                                'postedEmployedPerson': False,
#                                'employedTwoOrMoreStates': False,
#                                'postedSelfEmployedPerson': True,
#                                'selfEmployedTwoOrMoreStates': True,
#                                'civilServant': True,
#                                'contractStaff': False,
#                                'mariner': False,
#                                'employedAndSelfEmployed': False,
#                                'civilAndEmployedSelfEmployed': True,
#                                'flightCrewMember': False,
#                                'exception': False,
#                                'exceptionDescription': '',
#                                'workingInStateUnder21': False
#                            },
#                            'section4': {
#                                'employee': False,
#                                'selfEmployedActivity': True,
#                                'nameBusinessName': '1',
#                                'registeredAddress': {
#                                    'streetNo': '1, 1 1',
#                                    'postCode': '1',
#                                    'town': '1',
#                                    'countryCode': 'DE'
#                                }
#                            },
#                            'section5': {'noFixedAddress': True},
#                            'section6': {
#                                'name': 'National Institute for the Social Security of the
#            Self-employed (NISSE)',
#                                'address': {
#                                    'streetNo': 'Quai de Willebroeck 35',
#                                    'postCode': '1000',
#                                    'town': 'Bruxelles',
#                                    'countryCode': 'BE'
#                                },
#                                'institutionID': 'NSSIE/INASTI/RSVZ',
#                                'officeFaxNo': '',
#                                'officePhoneNo': '0800 12 018',
#                                'email': 'info@rsvz-inasti.fgov.be',
#                                'date': '2022-10-28',
#                                'signature': 'Official signature'
#                            },
#                            'id': 'did:ebsi:zbXStw5KgWJrW3U5YmbvAfgwnB1tssPCPPVMqPreKEiu5'
#                        },
#                        'credentialSchema': {
#                            'id':
#            'https://api-conformance.ebsi.eu/trusted-schemas-registry/v2/schemas/zGUR7RxCZtwQFSdwow6
#            3xF8hP2gMtH55incKsADwrcwzZ',
#                            'type': 'FullJsonSchemaValidator2021'
#                        },
#                        'expirationDate': '2033-02-12T19:36:53Z'
#                    }
#                },
#                'signature':
#            '3B3ziZtsKq6bBjsCXImu8qGAcBUp4TazZYH9Ocw4W_9AoL88MFk7jnUuUwOHmhRz-bt1MWu7kV3ZcNjV_74HIw'
#            ,
#                'data':
#            'eyJhbGciOiJFUzI1NksiLCJ0eXAiOiJKV1QiLCJraWQiOiJkaWQ6ZWJzaTp6Y2Zjd0dqTEJvamN6dzl5aG1VRkU
#            zWiNrZXlzLTEifQ.eyJqdGkiOiJ1cm46Y3JlZGVudGlhbDpybnR1bzo2ZmM3NzY5My1lYWFmLTRhNGQtODQ3ZS1h
#            MjMyMzdjMWYxNTAiLCJzdWIiOiJkaWQ6ZWJzaTp6YlhTdHc1S2dXSnJXM1U1WW1idkFmZ3duQjF0c3NQQ1BQVk1x
#            UHJlS0VpdTUiLCJpc3MiOiJkaWQ6ZWJzaTp6Y2Zjd0dqTEJvamN6dzl5aG1VRkUzWiIsIm5iZiI6MTY3NjIzMDYx
#            IjpmYWxzZSwiZW1wbG95ZWRBbmRTZWxmRW1wbG95ZWQiOmZhbHNlLCJjaXZpbEFuZEVtcGxveWVkU2VsZkVtcGxv
#            eWVkIjp0cnVlLCJmbGlnaHRDcmV3TWVtYmVyIjpmYWxzZSwiZXhjZXB0aW9uIjpmYWxzZSwiZXhjZXB0aW9uRGVz
#            Y3JpcHRpb24iOiIiLCJ3b3JraW5nSW5TdGF0ZVVuZGVyMjEiOmZhbHNlfSwic2VjdGlvbjQiOnsiZW1wbG95ZWUi
#            OmZhbHNlLCJzZWxmRW1wbG95ZWRBY3Rpdml0eSI6dHJ1ZSwibmFtZUJ1c2luZXNzTmFtZSI6IjEiLCJyZWdpc3Rl
#            cmVkQWRkcmVzcyI6eyJzdHJlZXRObyI6IjEsIDEgMSIsInBvc3RDb2RlIjoiMSIsInRvd24iOiIxIiwiY291bnRy
#            eUNvZGUiOiJERSJ9fSwic2VjdGlvbjUiOnsibm9GaXhlZEFkZHJlc3MiOnRydWV9LCJzZWN0aW9uNiI6eyJuYW1l
#            IjoiTmF0aW9uYWwgSW5zdGl0dXRlIGZvciB0aGUgU29jaWFsIFNlY3VyaXR5IG9mIHRoZSBTZWxmLWVtcGxveWVk
#            IChOSVNTRSkiLCJhZGRyZXNzIjp7InN0cmVldE5vIjoiUXVhaSBkZSBXaWxsZWJyb2VjayAzNSIsInBvc3RDb2Rl
#            IjoiMTAwMCIsInRvd24iOiJCcnV4ZWxsZXMiLCJjb3VudHJ5Q29kZSI6IkJFIn0sImluc3RpdHV0aW9uSUQiOiJO
#            U1NJRS9JTkFTVEkvUlNWWiIsIm9mZmljZUZheE5vIjoiIiwib2ZmaWNlUGhvbmVObyI6IjA4MDAgMTIgMDE4Iiwi
#            ZW1haWwiOiJpbmZvQHJzdnotaW5hc3RpLmZnb3YuYmUiLCJkYXRlIjoiMjAyMi0xMC0yOCIsInNpZ25hdHVyZSI6
#            Ik9mZmljaWFsIHNpZ25hdHVyZSJ9LCJpZCI6ImRpZDplYnNpOnpiWFN0dzVLZ1dKclczVTVZbWJ2QWZnd25CMXRz
#            c1BDUFBWTXFQcmVLRWl1NSJ9LCJjcmVkZW50aWFsU2NoZW1hIjp7ImlkIjoiaHR0cHM6Ly9hcGktY29uZm9ybWFu
#            Y2UuZWJzaS5ldS90cnVzdGVkLXNjaGVtYXMtcmVnaXN0cnkvdjIvc2NoZW1hcy96R1VSN1J4Q1p0d1FGU2R3b3c2
#            M3hGOGhQMmdNdEg1NWluY0tzQUR3cmN3eloiLCJ0eXBlIjoiRnVsbEpzb25TY2hlbWFWYWxpZGF0b3IyMDIxIn0s
#            ImV4cGlyYXRpb25EYXRlIjoiMjAzMy0wMi0xMlQxOTozNjo1M1oifX0'
#            }

# %% [markdown]
# ## VERIFY_011

# %%
headers = {
    "Conformance": headers.get("Conformance")
}
options = {
    "did_version": "v2"
}

result = await conformance("verifierAuthRequest", options=options, headers=headers)
console.log("verifierAuthRequest", result)
# Out:
# [01:06:54] verifierAuthRequest                                                                      ]8;id=571071;file:///tmp/ipykernel_51399/3364399777.py\3364399777.py]8;;\:]8;id=122004;file:///tmp/ipykernel_51399/3364399777.py#9\9]8;;\
#            {
#                'client_id':
#            'https://api-conformance.ebsi.eu/conformance/v2/verifier-mock/authentication-responses',
#                'response_type': 'id_token',
#                'scope': 'openid',
#                'claims':
#            '{"id_token":{"email":null},"vp_token":{"presentation_definition":{"id":"conformance_moc
#            k_vp_request","input_descriptors":[{"id":"conformance_mock_vp","name":"Conformance Mock
#            VP","purpose":"Only accept a VP containing a Conformance Mock
#            VA","constraints":{"fields":[{"path":["$.vc.credentialSchema"],"filter":{"allOf":[{"type
#            ":"array","contains":{"type":"object","properties":{"id":{"type":"string","pattern":"htt
#            ps://api-conformance.ebsi.eu/trusted-schemas-registry/v2/schemas/z3kRpVjUFj4Bq8qHRENUHiZ
#            rVF5VgMBUe7biEafp1wf2J"}},"required":["id"]}}]}}]}}],"format":{"jwt_vp":{"alg":["ES256K"
#            ]}}}}}',
#                'redirect_uri':
#            'https://api-conformance.ebsi.eu/conformance/v2/verifier-mock/authentication-responses',
#                'nonce': '1efa13d5-d1aa-4c83-b130-69c93d37d57f'
#            }

# %% [markdown]
# ### Create Verifiable Presentation JWT

# %%
from ebsi_wallet.main import compute

encoded_credential = issue_031_credential
credential_issuer = credential['payload']['iss']

options = {
    "credential": encoded_credential,
    "client": client,
    "issuer": credential_issuer,
    "audience": credential_issuer
}

jwt_vp = await compute("createPresentationJwt", options=options)
console.log("createPresentationJwt", jwt_vp)
# Out:
# [01:07:00] createPresentationJwt                                                                   ]8;id=441053;file:///tmp/ipykernel_51399/2803278071.py\2803278071.py]8;;\:]8;id=487054;file:///tmp/ipykernel_51399/2803278071.py#14\14]8;;\
#            {
#                'jwtVp':
#            'eyJhbGciOiAiRVMyNTZLIiwgInR5cCI6ICJKV1QiLCAia2lkIjogImRpZDplYnNpOnpiWFN0dzVLZ1dKclczVT
#            VZbWJ2QWZnd25CMXRzc1BDUFBWTXFQcmVLRWl1NSNBUG9QVFV1emNaX0NQQ1VaaFpYYkVvcHJNRk9xbkt4blM4d
#            nFBSDVPbHhnIiwgImp3ayI6IHsia3R5IjogIkVDIiwgImNydiI6ICJzZWNwMjU2azEiLCAieCI6ICJRWGJjVEF1
#            RVQ0TzJUdUpYbXFCOU9PYndaRURQeTRXNTNHblkxV1RtN2lVIiwgInkiOiAibDZndUwtdDdyanNBVjh2X3BHNXB
#            hazVsTEYyenp1ay1fUXEwVGtVbExYVSJ9fQ.eyJqdGkiOiAidXJuOmRpZDo0ZDYwMTNjZC1lMjVkLTRiODYtODc
#            zNS1mOTZhZTc5YjIzZmEiLCAic3ViIjogImRpZDplYnNpOnpiWFN0dzVLZ1dKclczVTVZbWJ2QWZnd25CMXRzc1
#            BDUFBWTXFQcmVLRWl1NSIsICJpc3MiOiAiZGlkOmVic2k6emJYU3R3NUtnV0pyVzNVNVltYnZBZmd3bkIxdHNzU
#            0ZzVTJOb1pXMWhJanA3SW1sa0lqb2lhSFIwY0hNNkx5OWhjR2t0WTI5dVptOXliV0Z1WTJVdVpXSnphUzVsZFM5
#            MGNuVnpkR1ZrTFhOamFHVnRZWE10Y21WbmFYTjBjbmt2ZGpJdmMyTm9aVzFoY3k5NlIxVlNOMUo0UTFwMGQxRkd
#            VMlIzYjNjMk0zaEdPR2hRTW1kTmRFZzFOV2x1WTB0elFVUjNjbU4zZWxvaUxDSjBlWEJsSWpvaVJuVnNiRXB6Yj
#            I1VFkyaGxiV0ZXWVd4cFpHRjBiM0l5TURJeEluMHNJbVY0Y0dseVlYUnBiMjVFWVhSbElqb2lNakF6TXkwd01pM
#            HhNbFF4T1Rvek5qbzFNMW9pZlgwLjNCM3ppWnRzS3E2YkJqc0NYSW11OHFHQWNCVXA0VGF6WllIOU9jdzRXXzlB
#            b0w4OE1GazdqblV1VXdPSG1oUnotYnQxTVd1N2tWM1pjTmpWXzc0SEl3Il19fQ.sEli93OcMOBDvCUOU05LfJT0
#            xyXEgJ85YM8APg4Kklk3uMHNjMgiziXm9ZRC5hTG9wQJQ9hOqT5KQo1ycOc0tQ',
#                'payload': {
#                    'id': 'urn:did:4d6013cd-e25d-4b86-8735-f96ae79b23fa',
#                    '@context': ['https://www.w3.org/2018/credentials/v1'],
#                    'type': ['VerifiablePresentation'],
#                    'holder': 'did:ebsi:zbXStw5KgWJrW3U5YmbvAfgwnB1tssPCPPVMqPreKEiu5',
#                    'verifiableCredential': [
#                        'eyJhbGciOiJFUzI1NksiLCJ0eXAiOiJKV1QiLCJraWQiOiJkaWQ6ZWJzaTp6Y2Zjd0dqTEJvam
#            N6dzl5aG1VRkUzWiNrZXlzLTEifQ.eyJqdGkiOiJ1cm46Y3JlZGVudGlhbDpybnR1bzo2ZmM3NzY5My1lYWFmLT
#            RhNGQtODQ3ZS1hMjMyMzdjMWYxNTAiLCJzdWIiOiJkaWQ6ZWJzaTp6YlhTdHc1S2dXSnJXM1U1WW1idkFmZ3duQ
#            jF0c3NQQ1BQVk1xUHJlS0VpdTUiLCJpc3MiOiJkaWQ6ZWJzaTp6Y2Zjd0dqTEJvamN6dzl5aG1VRkUzWiIsIm5i
#            ZiI6MTY3NjIzMDYxMywiZXhwIjoxOTkxODQ5ODEzLCJpYXQiOjE2NzYyMzA2MTMsInZjIjp7IkBjb250ZXh0Ijp
#            bImh0dHBzOi8vd3d3LnczLm9yZy8yMDE4L2NyZWRlbnRpYWxzL3YxIl0sImlkIjoidXJuOmNyZWRlbnRpYWw6cm
#            50dW86NmZjNzc2OTMtZWFhZi00YTRkLTg0N2UtYTIzMjM3YzFmMTUwIiwidHlwZSI6WyJWZXJpZmlhYmxlQ3JlZ
#            GVudGlhbCIsIlZlcmlmaWFibGVBdHRlc3RhdGlvbiIsIlZlcmlmaWFibGVQb3J0YWJsZURvY3VtZW50QTEiXSwi
#            FtZUJ1c2luZXNzTmFtZSI6IjEiLCJyZWdpc3RlcmVkQWRkcmVzcyI6eyJzdHJlZXRObyI6IjEsIDEgMSIsInBvc
#            3RDb2RlIjoiMSIsInRvd24iOiIxIiwiY291bnRyeUNvZGUiOiJERSJ9fSwic2VjdGlvbjUiOnsibm9GaXhlZEFk
#            ZHJlc3MiOnRydWV9LCJzZWN0aW9uNiI6eyJuYW1lIjoiTmF0aW9uYWwgSW5zdGl0dXRlIGZvciB0aGUgU29jaWF
#            sIFNlY3VyaXR5IG9mIHRoZSBTZWxmLWVtcGxveWVkIChOSVNTRSkiLCJhZGRyZXNzIjp7InN0cmVldE5vIjoiUX
#            VhaSBkZSBXaWxsZWJyb2VjayAzNSIsInBvc3RDb2RlIjoiMTAwMCIsInRvd24iOiJCcnV4ZWxsZXMiLCJjb3Vud
#            HJ5Q29kZSI6IkJFIn0sImluc3RpdHV0aW9uSUQiOiJOU1NJRS9JTkFTVEkvUlNWWiIsIm9mZmljZUZheE5vIjoi
#            Iiwib2ZmaWNlUGhvbmVObyI6IjA4MDAgMTIgMDE4IiwiZW1haWwiOiJpbmZvQHJzdnotaW5hc3RpLmZnb3YuYmU
#            iLCJkYXRlIjoiMjAyMi0xMC0yOCIsInNpZ25hdHVyZSI6Ik9mZmljaWFsIHNpZ25hdHVyZSJ9LCJpZCI6ImRpZD
#            plYnNpOnpiWFN0dzVLZ1dKclczVTVZbWJ2QWZnd25CMXRzc1BDUFBWTXFQcmVLRWl1NSJ9LCJjcmVkZW50aWFsU
#            2NoZW1hIjp7ImlkIjoiaHR0cHM6Ly9hcGktY29uZm9ybWFuY2UuZWJzaS5ldS90cnVzdGVkLXNjaGVtYXMtcmVn
#            aXN0cnkvdjIvc2NoZW1hcy96R1VSN1J4Q1p0d1FGU2R3b3c2M3hGOGhQMmdNdEg1NWluY0tzQUR3cmN3eloiLCJ
#            0eXBlIjoiRnVsbEpzb25TY2hlbWFWYWxpZGF0b3IyMDIxIn0sImV4cGlyYXRpb25EYXRlIjoiMjAzMy0wMi0xMl
#            QxOTozNjo1M1oifX0.3B3ziZtsKq6bBjsCXImu8qGAcBUp4TazZYH9Ocw4W_9AoL88MFk7jnUuUwOHmhRz-bt1M
#            Wu7kV3ZcNjV_74HIw'
#                    ]
#                }
#            }

# %% [markdown]
# ## VERIFY_031

# %%
options = {
    "credential": encoded_credential,
    "jwtVp": jwt_vp["jwtVp"],
    "client": client
}

vp_status = await conformance("verifierAuthResponse", options=options, headers={})
console.log("Verifiable presentation status", vp_status)
# Out:
# [01:07:06] Verifiable presentation status                                                           ]8;id=832810;file:///tmp/ipykernel_51399/3868489859.py\3868489859.py]8;;\:]8;id=317669;file:///tmp/ipykernel_51399/3868489859.py#8\8]8;;\
#            {
#                'result': True,
#                'validations': {
#                    'vpFormat': {'status': True},
#                    'presentation': {'status': True},
#                    'credential': {'status': True}
#                }
#            }
